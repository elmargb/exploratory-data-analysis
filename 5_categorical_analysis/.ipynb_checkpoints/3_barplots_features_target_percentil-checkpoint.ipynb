# %% [markdown]
# # Categorical analysis - all features are transformed into categorical variables

# %%
import os
# fix root path to save outputs
actual_path = os.path.abspath(os.getcwd())
list_root_path = actual_path.split('\\')[:-1]
root_path = '\\'.join(list_root_path)
os.chdir(root_path)
print('root path: ', root_path)
# Out:
# root path:  D:\github-mi-repo\Exploratory-data-analysis

# %% [markdown]
# ### 0. Package and load data

# %%
from sklearn.datasets import fetch_california_housing
import json
import pandas as pd
import numpy as np

# plotly
import plotly
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
from plotly.subplots import make_subplots

# %% [markdown]
# #### load data categorical features and target generated by percentiles
# This is generated in the notebook 0

# %%
data_percentile_feature_target = pd.read_pickle('data/df_cat_feature_target.pkl')
data_percentile_feature_target.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data_percentile_feature_target = pd.read_pickle('data/df_cat_feature_target.pkl')
#       2 data_percentile_feature_target.head()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# #### load data categorical only features generated by percentiles
# This is generated in the notebook 0

# %%
data_percentile_feature = pd.read_pickle('data/df_cat_feature.pkl')
data_percentile_feature.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data_percentile_feature = pd.read_pickle('data/df_cat_feature.pkl')
#       2 data_percentile_feature.head()
#
# NameError: name 'pd' is not defined

# %%
### DEFINE DATA TO USE
data = data_percentile_feature_target.copy()
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 ### DEFINE DATA TO USE
# ----> 2 data = data_percentile_feature_target.copy()
#       3 data.head()
#
# NameError: name 'data_percentile_feature_target' is not defined
